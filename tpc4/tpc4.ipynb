# %%
import random

lista = []

while True:
    print('========================================')
    print('(1) Criar Lista.')
    print('(2) Ler Lista.')
    print('(3) Soma.')
    print('(4) Média.')
    print('(5) Maior.')
    print('(6) Menor.')
    print('(7) estaOrdenada por ordem crescente.')
    print('(8) estaOrdenada por ordem decrescente.')
    print('(9) Procura um elemento.')
    print('(0) Sair.')
    print('========================================')
 
    escolha = int(input('Escolha uma opção:'))
    if escolha == 1:
          tamanho = -1
          while tamanho < 0:
              tamanho = int(input('Tamanho da lista:'))
          lista = [random.randint(1, 100) for _ in range(tamanho)]
    elif escolha == 2:
          tamanho = -1
          while tamanho < 0:
              tamanho = int(input('Tamanho da lista:'))
          lista = [int(input(f'Elemento {i + 1}:')) for i in range(tamanho)]
    elif escolha == 3:
          print(f'Soma: {sum(lista)}.')
    elif escolha == 4:
          if len(lista) > 0:
            print(f'Média: {sum(lista) / len(lista)}.')
          else:
            print('Lista vazia!')
    elif escolha == 5:
          if len(lista) > 0:
            print(f'Maior: {max(lista)}.')
          else:
            print('Lista vazia!')
    elif escolha == 6:
          if len(lista) > 0:
            print(f'Menor: {min(lista)}.')
          else:
            print('Lista vazia!')
    elif escolha == 7:
          if len(lista) > 0:
            if list(sorted(lista)) == lista:
                print('Sim.')
            else:
                print('Não.')
          else:
            print('Lista vazia!')
    elif escolha == 8:
          if len(lista) > 0:
            if list(sorted(lista, reverse=True)) == lista:
                print('Sim.')
            else:
                print('Não.')
          else:
            print('Lista vazia!')
    elif escolha == 9:
          if len(lista) > 0:
            elemento = int(input('Elemento a procurar:'))
            if elemento in lista:
                print(lista.index(elemento))
            else:
                print(-1)
          else:
            print('Lista vazia!')
    elif escolha == 0:
        print(f'Lista: {lista}')
# Out:
# ...
# (1) Criar Lista.
# (2) Ler Lista.
# (3) Soma.
# (4) Média.
# (5) Maior.
# (6) Menor.
# (7) estaOrdenada por ordem crescente.
# (8) estaOrdenada por ordem decrescente.
# (9) Procura um elemento.
# (0) Sair.
# ...
# (1) Criar Lista.
# (2) Ler Lista.
# (3) Soma.
# (4) Média.
# (5) Maior.
# (6) Menor.
# (7) estaOrdenada por ordem crescente.
# (8) estaOrdenada por ordem decrescente.
# (9) Procura um elemento.
# (0) Sair.
# ...
# (1) Criar Lista.
# (2) Ler Lista.
# (3) Soma.
# (4) Média.
# (5) Maior.
# (6) Menor.
# (7) estaOrdenada por ordem crescente.
# (8) estaOrdenada por ordem decrescente.
# (9) Procura um elemento.
# (0) Sair.
# ...
# Média: 2.5.
# ...
# (1) Criar Lista.
# (2) Ler Lista.
# (3) Soma.
# (4) Média.
# (5) Maior.
# (6) Menor.
# (7) estaOrdenada por ordem crescente.
# (8) estaOrdenada por ordem decrescente.
# (9) Procura um elemento.
# (0) Sair.
# ...
